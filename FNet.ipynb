# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhtasimMahadi/Muhtasim_Hossain/blob/main/FNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

DATADIR = "/content/drive/MyDrive/titl_defence/Dataset/final_crop_image"

CATEGORIES = ["Common_rust", "gray_leaf_spot", "healthy"]

for category in CATEGORIES:  # do dogs and cats
    path = os.path.join(DATADIR,category)  # create path to dogs and cats
    for img in os.listdir(path):  # iterate over each image per dogs and cats
        img_array = cv2.imread(os.path.join(path,img))  # convert to array
        plt.imshow(img_array, cmap='gray')  # graph it
        plt.show()  # display!

        break  # we just want one for now so break
    break  #...and one more!

# %%
IMG_SIZE = 32

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array)
plt.show()

# %%
training_data = []

def create_training_data():
    for category in CATEGORIES:  # do dogs and cats

        path = os.path.join(DATADIR,category)  # create path to dogs and cats
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=dog 1=cat

        for img in tqdm(os.listdir(path)):  # iterate over each image per dogs and cats
            try:
                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))

create_training_data()
# Out:
# 100%|██████████| 3650/3650 [01:25<00:00, 42.72it/s]
# 100%|██████████| 3550/3550 [02:23<00:00, 24.71it/s]
# 100%|██████████| 3450/3450 [03:30<00:00, 16.37it/s]

# %%
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)
X = np.array(X) / 255
X.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y = np.array(y)

# %%
num_classes = 43
input_shape = (32, 32, 3)

#x_train, y_train, x_test, y_test = train_test_split(X, y, test_size=0.2)
(x_train, x_test, y_train, y_test) = train_test_split(X, y,
    test_size=0.2)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (8520, 32, 32, 3) - y_train shape: (8520,)
# x_test shape: (2130, 32, 32, 3) - y_test shape: (2130,)

# %%
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
dropout_rate = 0.2
image_size = 64  # We'll resize input images to this size.
patch_size = 8  # Size of the patches to be extracted from the input images.
num_patches = (image_size // patch_size) ** 2  # Size of the data array.
embedding_dim = 256  # Number of hidden units.
num_blocks = 4  # Number of blocks.

print(f"Image size: {image_size} X {image_size} = {image_size ** 2}")
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
print(f"Elements per patch (3 channels): {(patch_size ** 2) * 3}")
# Out:
# Image size: 64 X 64 = 4096
# Patch size: 8 X 8 = 64
# Patches per image: 64
# Elements per patch (3 channels): 192

# %%
def build_classifier(blocks, positional_encoding=False):
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size, num_patches)(augmented)
    # Encode patches to generate a [batch_size, num_patches, embedding_dim] tensor.
    x = layers.Dense(units=embedding_dim)(patches)
    if positional_encoding:
        positions = tf.range(start=0, limit=num_patches, delta=1)
        position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=embedding_dim
        )(positions)
        x = x + position_embedding
    # Process x using the module blocks.
    x = blocks(x)
    # Apply global average pooling to generate a [batch_size, embedding_dim] representation tensor.
    representation = layers.GlobalAveragePooling1D()(x)
    # Apply dropout.
    representation = layers.Dropout(rate=dropout_rate)(representation)
    # Compute logits outputs.
    logits = layers.Dense(num_classes)(representation)
    # Create the Keras model.
    return keras.Model(inputs=inputs, outputs=logits)

# %%
def run_experiment(model):
    # Create Adam optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay,
    )
    # Compile the model.
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="acc"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top5-acc"),
        ],
    )
    # Create a learning rate scheduler callback.
    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5
    )
    # Create an early stopping callback.
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[early_stopping, reduce_lr],
    )

    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    # Return history to plot learning curves.
    return history

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size, num_patches):
        super(Patches, self).__init__()
        self.patch_size = patch_size
        self.num_patches = num_patches

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, self.num_patches, patch_dims])
        return patches

# %% [markdown]
# FNet model

# %%
class FNetLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super(FNetLayer, self).__init__(*args, **kwargs)

        self.ffn = keras.Sequential(
            [
                layers.Dense(units=embedding_dim),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
                layers.Dense(units=embedding_dim),
            ]
        )

        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        # Apply fourier transformations.
        x = tf.cast(
            tf.signal.fft2d(tf.cast(inputs, dtype=tf.dtypes.complex64)),
            dtype=tf.dtypes.float32,
        )
        # Add skip connection.
        x = x + inputs
        # Apply layer normalization.
        x = self.normalize1(x)
        # Apply Feedfowrad network.
        x_ffn = self.ffn(x)
        # Add skip connection.
        x = x + x_ffn
        # Apply layer normalization.
        return self.normalize2(x)

# %%
fnet_blocks = keras.Sequential(
    [FNetLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
learning_rate = 0.001
fnet_classifier = build_classifier(fnet_blocks, positional_encoding=True)
history = run_experiment(fnet_classifier)
# Out:
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 59/60 [============================>.] - ETA: 0s - loss: 0.8681 - acc: 0.6332 - top5-acc: 0.9873
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 60/60 [==============================] - 15s 66ms/step - loss: 0.8634 - acc: 0.6347 - top5-acc: 0.9875 - val_loss: 0.5729 - val_acc: 0.7512 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 2/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.5403 - acc: 0.7753 - top5-acc: 1.0000 - val_loss: 0.4523 - val_acc: 0.8263 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 3/100
# 60/60 [==============================] - 4s 59ms/step - loss: 0.4087 - acc: 0.8284 - top5-acc: 1.0000 - val_loss: 0.3343 - val_acc: 0.8533 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 4/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.3290 - acc: 0.8675 - top5-acc: 1.0000 - val_loss: 0.2696 - val_acc: 0.8920 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 5/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.2301 - acc: 0.9075 - top5-acc: 1.0000 - val_loss: 0.1818 - val_acc: 0.9167 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 6/100
# 60/60 [==============================] - 3s 58ms/step - loss: 0.1983 - acc: 0.9214 - top5-acc: 1.0000 - val_loss: 0.1577 - val_acc: 0.9261 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 7/100
# 60/60 [==============================] - 4s 60ms/step - loss: 0.1588 - acc: 0.9384 - top5-acc: 1.0000 - val_loss: 0.1832 - val_acc: 0.9331 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 8/100
# 60/60 [==============================] - 3s 58ms/step - loss: 0.1305 - acc: 0.9521 - top5-acc: 1.0000 - val_loss: 0.0780 - val_acc: 0.9695 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 9/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.1321 - acc: 0.9491 - top5-acc: 1.0000 - val_loss: 0.0849 - val_acc: 0.9660 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 10/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.1079 - acc: 0.9611 - top5-acc: 1.0000 - val_loss: 0.1077 - val_acc: 0.9636 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 11/100
# 60/60 [==============================] - 4s 61ms/step - loss: 0.0771 - acc: 0.9713 - top5-acc: 1.0000 - val_loss: 0.0915 - val_acc: 0.9624 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 12/100
# 60/60 [==============================] - 4s 61ms/step - loss: 0.1112 - acc: 0.9605 - top5-acc: 1.0000 - val_loss: 0.0784 - val_acc: 0.9707 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 13/100
# 60/60 [==============================] - 3s 57ms/step - loss: 0.0753 - acc: 0.9737 - top5-acc: 1.0000 - val_loss: 0.0895 - val_acc: 0.9671 - val_top5-acc: 1.0000 - lr: 0.0010
# Epoch 14/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0455 - acc: 0.9832 - top5-acc: 1.0000 - val_loss: 0.0282 - val_acc: 0.9871 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 15/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0284 - acc: 0.9890 - top5-acc: 1.0000 - val_loss: 0.0139 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 16/100
# 60/60 [==============================] - 3s 58ms/step - loss: 0.0349 - acc: 0.9872 - top5-acc: 1.0000 - val_loss: 0.0287 - val_acc: 0.9906 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 17/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0419 - acc: 0.9849 - top5-acc: 1.0000 - val_loss: 0.0353 - val_acc: 0.9894 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 18/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.0351 - acc: 0.9876 - top5-acc: 1.0000 - val_loss: 0.0232 - val_acc: 0.9894 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 19/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.0315 - acc: 0.9889 - top5-acc: 1.0000 - val_loss: 0.0135 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 20/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.0347 - acc: 0.9887 - top5-acc: 1.0000 - val_loss: 0.0481 - val_acc: 0.9836 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 21/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0290 - acc: 0.9896 - top5-acc: 1.0000 - val_loss: 0.0274 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 22/100
# 60/60 [==============================] - 4s 60ms/step - loss: 0.0210 - acc: 0.9930 - top5-acc: 1.0000 - val_loss: 0.0285 - val_acc: 0.9918 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 23/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0319 - acc: 0.9893 - top5-acc: 1.0000 - val_loss: 0.0168 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 24/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0260 - acc: 0.9913 - top5-acc: 1.0000 - val_loss: 0.0279 - val_acc: 0.9894 - val_top5-acc: 1.0000 - lr: 5.0000e-04
# Epoch 25/100
# 60/60 [==============================] - 3s 57ms/step - loss: 0.0100 - acc: 0.9970 - top5-acc: 1.0000 - val_loss: 0.0056 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 26/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0124 - acc: 0.9965 - top5-acc: 1.0000 - val_loss: 0.0272 - val_acc: 0.9918 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 27/100
# 60/60 [==============================] - 3s 57ms/step - loss: 0.0081 - acc: 0.9977 - top5-acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 28/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0092 - acc: 0.9967 - top5-acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 29/100
# 60/60 [==============================] - 3s 56ms/step - loss: 0.0117 - acc: 0.9957 - top5-acc: 1.0000 - val_loss: 0.0085 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 30/100
# 60/60 [==============================] - 4s 61ms/step - loss: 0.0126 - acc: 0.9962 - top5-acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9894 - val_top5-acc: 1.0000 - lr: 2.5000e-04
# Epoch 31/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0082 - acc: 0.9974 - top5-acc: 1.0000 - val_loss: 0.0138 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 1.2500e-04
# Epoch 32/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0072 - acc: 0.9980 - top5-acc: 1.0000 - val_loss: 0.0091 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 1.2500e-04
# Epoch 33/100
# 60/60 [==============================] - 3s 54ms/step - loss: 0.0071 - acc: 0.9986 - top5-acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 1.2500e-04
# Epoch 34/100
# 60/60 [==============================] - 3s 55ms/step - loss: 0.0073 - acc: 0.9977 - top5-acc: 1.0000 - val_loss: 0.0064 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 1.2500e-04
# Epoch 35/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0077 - acc: 0.9977 - top5-acc: 1.0000 - val_loss: 0.0075 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 1.2500e-04
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0046 - acc: 0.9986 - top5-acc: 1.0000
# Test accuracy: 99.86%
# Test top 5 accuracy: 100.0%

# %% [markdown]
# gMLP model

# %%
class gMLPLayer(layers.Layer):
    def __init__(self, num_patches, embedding_dim, dropout_rate, *args, **kwargs):
        super(gMLPLayer, self).__init__(*args, **kwargs)

        self.channel_projection1 = keras.Sequential(
            [
                layers.Dense(units=embedding_dim * 2),
                tfa.layers.GELU(),
                layers.Dropout(rate=dropout_rate),
            ]
        )

        self.channel_projection2 = layers.Dense(units=embedding_dim)

        self.spatial_projection = layers.Dense(
            units=num_patches, bias_initializer="Ones"
        )

        self.normalize1 = layers.LayerNormalization(epsilon=1e-6)
        self.normalize2 = layers.LayerNormalization(epsilon=1e-6)

    def spatial_gating_unit(self, x):
        # Split x along the channel dimensions.
        # Tensors u and v will in th shape of [batch_size, num_patchs, embedding_dim].
        u, v = tf.split(x, num_or_size_splits=2, axis=2)
        # Apply layer normalization.
        v = self.normalize2(v)
        # Apply spatial projection.
        v_channels = tf.linalg.matrix_transpose(v)
        v_projected = self.spatial_projection(v_channels)
        v_projected = tf.linalg.matrix_transpose(v_projected)
        # Apply element-wise multiplication.
        return u * v_projected

    def call(self, inputs):
        # Apply layer normalization.
        x = self.normalize1(inputs)
        # Apply the first channel projection. x_projected shape: [batch_size, num_patches, embedding_dim * 2].
        x_projected = self.channel_projection1(x)
        # Apply the spatial gating unit. x_spatial shape: [batch_size, num_patches, embedding_dim].
        x_spatial = self.spatial_gating_unit(x_projected)
        # Apply the second channel projection. x_projected shape: [batch_size, num_patches, embedding_dim].
        x_projected = self.channel_projection2(x_spatial)
        # Add skip connection.
        return x + x_projected

# %%
gmlp_blocks = keras.Sequential(
    [gMLPLayer(num_patches, embedding_dim, dropout_rate) for _ in range(num_blocks)]
)
learning_rate = 0.003
gmlp_classifier = build_classifier(gmlp_blocks)
history = run_experiment(gmlp_classifier)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 16s 88ms/step - loss: 0.7924 - acc: 0.7115 - top5-acc: 0.9842 - val_loss: 0.3820 - val_acc: 0.8439 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 2/100
# 60/60 [==============================] - 4s 72ms/step - loss: 0.3141 - acc: 0.8788 - top5-acc: 1.0000 - val_loss: 0.1956 - val_acc: 0.9284 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 3/100
# 60/60 [==============================] - 4s 73ms/step - loss: 0.1792 - acc: 0.9311 - top5-acc: 1.0000 - val_loss: 0.1185 - val_acc: 0.9577 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 4/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.1294 - acc: 0.9542 - top5-acc: 1.0000 - val_loss: 0.1004 - val_acc: 0.9624 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 5/100
# 60/60 [==============================] - 4s 68ms/step - loss: 0.1140 - acc: 0.9604 - top5-acc: 1.0000 - val_loss: 0.0826 - val_acc: 0.9742 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 6/100
# 60/60 [==============================] - 4s 70ms/step - loss: 0.0855 - acc: 0.9703 - top5-acc: 1.0000 - val_loss: 0.0657 - val_acc: 0.9777 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 7/100
# 60/60 [==============================] - 4s 73ms/step - loss: 0.0785 - acc: 0.9734 - top5-acc: 1.0000 - val_loss: 0.1203 - val_acc: 0.9707 - val_top5-acc: 0.9988 - lr: 0.0030
# Epoch 8/100
# 60/60 [==============================] - 4s 68ms/step - loss: 0.0643 - acc: 0.9761 - top5-acc: 1.0000 - val_loss: 0.0664 - val_acc: 0.9777 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 9/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0916 - acc: 0.9691 - top5-acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.9789 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 10/100
# 60/60 [==============================] - 4s 72ms/step - loss: 0.0454 - acc: 0.9830 - top5-acc: 1.0000 - val_loss: 0.0406 - val_acc: 0.9847 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 11/100
# 60/60 [==============================] - 4s 74ms/step - loss: 0.0501 - acc: 0.9824 - top5-acc: 1.0000 - val_loss: 0.0508 - val_acc: 0.9824 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 12/100
# 60/60 [==============================] - 4s 69ms/step - loss: 0.0431 - acc: 0.9845 - top5-acc: 1.0000 - val_loss: 0.0339 - val_acc: 0.9871 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 13/100
# 60/60 [==============================] - 4s 68ms/step - loss: 0.0367 - acc: 0.9880 - top5-acc: 1.0000 - val_loss: 0.0381 - val_acc: 0.9871 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 14/100
# 60/60 [==============================] - 4s 75ms/step - loss: 0.0407 - acc: 0.9855 - top5-acc: 1.0000 - val_loss: 0.0327 - val_acc: 0.9883 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 15/100
# 60/60 [==============================] - 4s 71ms/step - loss: 0.0375 - acc: 0.9868 - top5-acc: 1.0000 - val_loss: 0.0840 - val_acc: 0.9789 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 16/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0380 - acc: 0.9874 - top5-acc: 1.0000 - val_loss: 0.0326 - val_acc: 0.9871 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 17/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0485 - acc: 0.9838 - top5-acc: 1.0000 - val_loss: 0.0437 - val_acc: 0.9859 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 18/100
# 60/60 [==============================] - 5s 85ms/step - loss: 0.0305 - acc: 0.9902 - top5-acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 19/100
# 60/60 [==============================] - 5s 83ms/step - loss: 0.0205 - acc: 0.9943 - top5-acc: 1.0000 - val_loss: 0.0350 - val_acc: 0.9918 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 20/100
# 60/60 [==============================] - 4s 69ms/step - loss: 0.0337 - acc: 0.9896 - top5-acc: 1.0000 - val_loss: 0.0312 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 21/100
# 60/60 [==============================] - 4s 69ms/step - loss: 0.0366 - acc: 0.9877 - top5-acc: 1.0000 - val_loss: 0.0345 - val_acc: 0.9847 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 22/100
# 60/60 [==============================] - 4s 74ms/step - loss: 0.0264 - acc: 0.9913 - top5-acc: 1.0000 - val_loss: 0.0214 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 23/100
# 60/60 [==============================] - 4s 68ms/step - loss: 0.0489 - acc: 0.9841 - top5-acc: 1.0000 - val_loss: 0.0330 - val_acc: 0.9894 - val_top5-acc: 1.0000 - lr: 0.0030
# Epoch 24/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0136 - acc: 0.9958 - top5-acc: 1.0000 - val_loss: 0.0260 - val_acc: 0.9918 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 25/100
# 60/60 [==============================] - 4s 71ms/step - loss: 0.0113 - acc: 0.9963 - top5-acc: 1.0000 - val_loss: 0.0189 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 26/100
# 60/60 [==============================] - 4s 74ms/step - loss: 0.0055 - acc: 0.9984 - top5-acc: 1.0000 - val_loss: 0.0167 - val_acc: 0.9953 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 27/100
# 60/60 [==============================] - 4s 68ms/step - loss: 0.0061 - acc: 0.9984 - top5-acc: 1.0000 - val_loss: 0.0159 - val_acc: 0.9953 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 28/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0050 - acc: 0.9982 - top5-acc: 1.0000 - val_loss: 0.0099 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 29/100
# 60/60 [==============================] - 4s 71ms/step - loss: 0.0057 - acc: 0.9980 - top5-acc: 1.0000 - val_loss: 0.0473 - val_acc: 0.9930 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 30/100
# 60/60 [==============================] - 5s 76ms/step - loss: 0.0081 - acc: 0.9963 - top5-acc: 1.0000 - val_loss: 0.0158 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 31/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0049 - acc: 0.9982 - top5-acc: 1.0000 - val_loss: 0.0140 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 32/100
# 60/60 [==============================] - 4s 69ms/step - loss: 0.0078 - acc: 0.9975 - top5-acc: 1.0000 - val_loss: 0.0089 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 33/100
# 60/60 [==============================] - 4s 72ms/step - loss: 0.0081 - acc: 0.9969 - top5-acc: 1.0000 - val_loss: 0.0058 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 34/100
# 60/60 [==============================] - 4s 72ms/step - loss: 0.0068 - acc: 0.9980 - top5-acc: 1.0000 - val_loss: 0.0134 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 35/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0068 - acc: 0.9977 - top5-acc: 1.0000 - val_loss: 0.0073 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 36/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0051 - acc: 0.9980 - top5-acc: 1.0000 - val_loss: 0.0029 - val_acc: 0.9988 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 37/100
# 60/60 [==============================] - 4s 70ms/step - loss: 0.0097 - acc: 0.9971 - top5-acc: 1.0000 - val_loss: 0.0182 - val_acc: 0.9953 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 38/100
# 60/60 [==============================] - 5s 75ms/step - loss: 0.0111 - acc: 0.9963 - top5-acc: 1.0000 - val_loss: 0.0110 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 39/100
# 60/60 [==============================] - 4s 70ms/step - loss: 0.0112 - acc: 0.9966 - top5-acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9953 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 40/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0061 - acc: 0.9980 - top5-acc: 1.0000 - val_loss: 0.0131 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 41/100
# 60/60 [==============================] - 4s 74ms/step - loss: 0.0040 - acc: 0.9990 - top5-acc: 1.0000 - val_loss: 0.0255 - val_acc: 0.9941 - val_top5-acc: 1.0000 - lr: 0.0015
# Epoch 42/100
# 60/60 [==============================] - 4s 71ms/step - loss: 0.0025 - acc: 0.9991 - top5-acc: 1.0000 - val_loss: 0.0154 - val_acc: 0.9953 - val_top5-acc: 1.0000 - lr: 7.5000e-04
# Epoch 43/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0040 - acc: 0.9987 - top5-acc: 1.0000 - val_loss: 0.0101 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 7.5000e-04
# Epoch 44/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0013 - acc: 0.9995 - top5-acc: 1.0000 - val_loss: 0.0098 - val_acc: 0.9965 - val_top5-acc: 1.0000 - lr: 7.5000e-04
# Epoch 45/100
# 60/60 [==============================] - 4s 74ms/step - loss: 0.0017 - acc: 0.9993 - top5-acc: 1.0000 - val_loss: 0.0071 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 7.5000e-04
# Epoch 46/100
# 60/60 [==============================] - 4s 71ms/step - loss: 0.0011 - acc: 0.9996 - top5-acc: 1.0000 - val_loss: 0.0084 - val_acc: 0.9977 - val_top5-acc: 1.0000 - lr: 7.5000e-04
# 67/67 [==============================] - 1s 13ms/step - loss: 0.0014 - acc: 0.9991 - top5-acc: 1.0000
# Test accuracy: 99.91%
# Test top 5 accuracy: 100.0%
